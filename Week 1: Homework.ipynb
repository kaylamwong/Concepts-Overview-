# %% [markdown]
# # Week 1: Homework

# %% [markdown]
# Problem 1:
#
# Set p1 to the integer 3.

# %%
p1 = 3

# %%
p1
# Out:
# 3

# %% [markdown]
# Problem 2:
#
# Set p2 to the real number 3.0. p2 should be a Python float.

# %%
p2 = 3.0

# %%
p2
# Out:
# 3.0

# %% [markdown]
# Problem 3:
#
# Set the variable p3 to the sum of one, three, and six. Don't worry about being clever, and just answer directly.

# %%
p3 = 1 + 3 + 6

# %%
p3
# Out:
# 10

# %% [markdown]
# Problem 4:
#
# Write a function p4 that takes in three arguments and returns their sum.

# %%
def p4(a, b, c):
    return a + b + c

# %%
p4(0, 0 , 0)
# Out:
# 0

# %%
p4(1, 2, 3)
# Out:
# 6

# %% [markdown]
# Problem 5:
#
# Write a function p5 that takes in two arguments and returns True if they are equal and False otherwise.

# %%
def p5(x, y):
    return x == y

# %%
p5 (0, 0)
# Out:
# True

# %%
p5("x", "y")
# Out:
# False

# %%
p5(3.4, 5)
# Out:
# False

# %% [markdown]
# Problem 6:
#
# Set the variable p6 to be one third.

# %%
p6 = 1/3

# %%
p6
# Out:
# 0.3333333333333333

# %% [markdown]
# Problem 7:
#
# Set the variable p7 to be two and one fifth.

# %%
p7 = 11/5

# %%
p7
# Out:
# 2.2

# %% [markdown]
# Problem 8:
#
# We often see the size of the approximation errors by taking a round looking decimal number, say 3.3, and subtracting out the whole numbers. In this case, that would be 3.3 - 3. If you then subtract the original fractional part, 0.3 in this case, you can see the accumulated error. So that calculation is (3.3 - 3) - 0.3. Set p8 to that value.

# %%
p8 = (3.3 - 3) - 0.3

# %%
p8
# Out:
# -1.6653345369377348e-16

# %% [markdown]
# Problem 9:
#
# The speed of light is approximately 3 x 10 **8 meters per second. One kilometer is 10 ** 3 meters. Set p9 to the speed of light in kilometers per second.

# %%
p9 = 3e5

# %%
p9
# Out:
# 300000.0

# %% [markdown]
# Problem 10:
#
# The following code imports the math module, giving access to functions defined in the module.

# %%
import math

# %% [markdown]
# For example, the sine function from trigonometry is math.sin. Note that it is called "sin", not "sine", in that module. To call that function with input zero, use math.sin(0).

# %%
math.sin(0)
# Out:
# 0.0

# %% [markdown]
# Set p10 to be sin(1).

# %%
p10= math.sin(1)

# %%
p10
# Out:
# 0.8414709848078965

# %% [markdown]
# Problem 11:
#
# The math module includes many other commonly used functions. The documentation for the math module is here -
#
# https://docs.python.org/3/library/math.html

# %% [markdown]
# Find the function to calculate e^x (e to the x'th power), and use it to set p11 equal to e^3.

# %%
import math

p11= math.exp(3)

# %%
p11
# Out:
# 20.085536923187668

# %% [markdown]
# Problem 12:
#
# Use the math module again to set p12 to the square root of 3.

# %%
import math

p12= math.sqrt(3)

# %%
p12
# Out:
# 1.7320508075688772

# %% [markdown]
# Problem 13:
#
# Set p13 to the mathematical constant (pi). Use the math module to get the best floating point approximation.

# %%
import math 

p13= math.pi

# %%
p13
# Out:
# 3.141592653589793

# %% [markdown]
# Problem 14:
#
# Set p14 to 14!

# %%
import math 

p14= math.factorial(14)

# %%
p14
# Out:
# 87178291200

# %% [markdown]
# Problem 15:
#
# Write a function p15 that takes in three inputs a, b, c, and returns the value 3a + 4b - 5c + 6.

# %%
def p15(a, b, c):
    return 3*a + 4*b - 5*c + 6

# %%
p15(0, 0, 0)
# Out:
# 6

# %%
p15(1, 1, 1)
# Out:
# 8

# %%
p15(1.0, 2.0, 3.0)
# Out:
# 2.0

# %% [markdown]
# Problem 16:
#
# Write a function p16 that takes in two inputs a and b, and returns cos(a)+b.

# %%
import math 

def p16(a, b): 
    return math.cos(a) + b

# %% [markdown]
# Problem 17:
#
# Set p17 to be the type of the expression 3 + 4 / 5.

# %%
p17 = type(3 + 4 / 5)

# %% [markdown]
# Problem 18:
#
# Write a function p18 that returns the sum of its two inputs.

# %%
def p18(a, b): 
    return a + b

# %% [markdown]
# Problem 19:
#
# Set p19 to pi - 22/7 using the math module to get the value for pi.

# %%
import math 

p19= math.pi - (22/7)

p19
# Out:
# -0.0012644892673496777
