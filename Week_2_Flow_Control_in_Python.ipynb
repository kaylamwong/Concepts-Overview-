# %% [markdown]
# # Week 2: Flow Control in Python
#
# - Flow control gives the programmer the ability to pick what code runs next instead of running through the statements in a straight line Flow control lets actions be skipped or repeated until the conditions are right. It enables the program to adapt to the conditions and data, instead of assuming a rigid one-size-fits-all approach. Without flow control, your program will break if the number of data rows changes!
